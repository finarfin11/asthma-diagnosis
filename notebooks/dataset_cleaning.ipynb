# %%
# %cd ..
# Out:
# D:\SoftUni\Data Science\7. Data science project architecture\07.Lab

# %%
import pandas as pd
from src import functions

# %%
asthma_data = pd.read_csv('data/asthma_disease_data.csv')

# %% [markdown]
# ### Columns names

# %%
asthma_data.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'PollutionExposure', 'PollenExposure', 'DustExposure', 'PetAllergy',
#        'FamilyHistoryAsthma', 'HistoryOfAllergies', 'Eczema', 'HayFever',
#        'GastroesophagealReflux', 'LungFunctionFEV1', 'LungFunctionFVC',
#        'Wheezing', 'ShortnessOfBreath', 'ChestTightness', 'Coughing',
#        'NighttimeSymptoms', 'ExerciseInduced', 'Diagnosis', 'DoctorInCharge'],
#       dtype='object')

# %% [markdown]
# All columns names are Pascal cased. Snake case will be more appropriate here.

# %%
asthma_data.rename(functions.to_snake_case, axis = 'columns', inplace = True)

# %%
asthma_data.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'ethnicity', 'education_level', 'bmi',
#        'smoking', 'physical_activity', 'diet_quality', 'sleep_quality',
#        'pollution_exposure', 'pollen_exposure', 'dust_exposure', 'pet_allergy',
#        'family_history_asthma', 'history_of_allergies', 'eczema', 'hay_fever',
#        'gastroesophageal_reflux', 'lung_function_fev1', 'lung_function_fvc',
#        'wheezing', 'shortness_of_breath', 'chest_tightness', 'coughing',
#        'nighttime_symptoms', 'exercise_induced', 'diagnosis',
#        'doctor_in_charge'],
#       dtype='object')

# %% [markdown]
# ### Rounding
# For better readability, I round the floats to the second decimal place.

# %%
asthma_data = asthma_data.round(2)

# %%
asthma_data.sample(5)
# Out:
#       patient_id  age  gender  ethnicity  education_level    bmi  smoking  \
# 1818        6852   43       1          1                0  31.58        0
# 101         5135   28       1          0                2  18.16        0
# 2089        7123   31       1          0                1  36.95        0
# 1501        6535   19       0          2                0  33.44        0
# 1131        6165   51       1          1                1  32.72        0
#
#       physical_activity  diet_quality  sleep_quality  ...  lung_function_fev1  \
# 1818               5.94          4.09           9.37  ...                1.76
# 101                0.67          8.65           7.82  ...                1.44
# 2089               5.90          0.66           5.29  ...                1.45
# 1501               6.12          7.35           8.29  ...                3.35
# 1131               4.94          2.36           5.37  ...                2.63
#
# ...

# %% [markdown]
# ### Doctor in charge
#
# This column has only one unique value for all observations. It is because the information is confidential. Since this column has no real value for the analysis, it is safe to delete it.

# %%
asthma_data.drop(columns = ['doctor_in_charge'], inplace = True)

# %%
asthma_data.sample(5)
# Out:
#       patient_id  age  gender  ethnicity  education_level    bmi  smoking  \
# 689         5723   36       0          1                0  36.03        0
# 1469        6503   32       0          0                0  16.81        0
# 2132        7166   72       0          0                1  36.95        0
# 248         5282   67       0          0                1  21.06        0
# 2127        7161   39       1          0                2  24.74        0
#
#       physical_activity  diet_quality  sleep_quality  ...  \
# 689                1.89          5.95           6.95  ...
# 1469               3.01          7.15           6.60  ...
# 2132               0.70          4.43           6.03  ...
# 248                8.24          9.01           7.70  ...
# 2127               7.66          6.52           4.04  ...
#
#       gastroesophageal_reflux  lung_function_fev1  lung_function_fvc  \
# 689                         0                2.23               5.06
# ...

# %% [markdown]
# ### Patient id
#
# Since all observations are indexed by Pandas, there are two index columns. Dropping 'patient_id' column and leave indexes starting from zero.

# %%
asthma_data.drop(columns = ['patient_id'], inplace = True)

# %%
asthma_data.sample(2)
# Out:
#       age  gender  ethnicity  education_level    bmi  smoking  \
# 497    58       1          1                0  26.45        0
# 1937   64       0          0                0  22.34        0
#
#       physical_activity  diet_quality  sleep_quality  pollution_exposure  ...  \
# 497                3.10          5.39           8.81                9.59  ...
# 1937               7.33          7.57           9.14                2.65  ...
#
#       gastroesophageal_reflux  lung_function_fev1  lung_function_fvc  \
# 497                         0                2.84               5.96
# 1937                        1                1.24               1.85
#
#       wheezing  shortness_of_breath  chest_tightness  coughing  \
# 497          0                    1                1         1
# 1937         0                    1                1         1
#
#       nighttime_symptoms  exercise_induced  diagnosis
# 497                    0                 1          0
# ...

# %%
asthma_data_cleaned = pd.

# %%
# Save a copy of cleaned dataframe for further exploration to 'data/asthma_data_cleaned.csv'
asthma_data.to_csv('data/asthma_data_cleaned.csv', index=False)
